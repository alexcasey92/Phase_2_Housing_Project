# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
df = pd.read_csv("data/kc_house_data.csv")
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.groupby('zipcode').count().shape
# Out:
# (70, 20)

# %%
dfbyzip = df[['zipcode', 'price', 'bedrooms', 'sqft_living', 'yr_built']].groupby('zipcode').mean()
dfbyzip.head()
# Out:
#                 price  bedrooms  sqft_living     yr_built
# zipcode
# 98001    2.811949e+05  3.393352  1903.783934  1980.867036
# 98002    2.342840e+05  3.326633  1627.743719  1967.773869
# 98003    2.941113e+05  3.357143  1928.882143  1976.885714
# 98004    1.356524e+06  3.854890  2909.022082  1971.470032
# 98005    8.102897e+05  3.851190  2656.803571  1969.744048

# %%
import math
dfbyzip = df[['zipcode', 'price', 'bedrooms', 'sqft_living', 'yr_built']].groupby('zipcode').mean() \
    .agg({ 'price': int, 'bedrooms':int, 'sqft_living':int, 'yr_built':int})
dfbyzip.head()
# Out:
#            price  bedrooms  sqft_living  yr_built
# zipcode
# 98001     281194         3         1903      1980
# 98002     234284         3         1627      1967
# 98003     294111         3         1928      1976
# 98004    1356523         3         2909      1971
# 98005     810289         3         2656      1969

# %%
dfdescribebyzip = df[['zipcode', 'price', 'bedrooms', 'sqft_living', 'yr_built']].groupby('zipcode').describe()
dfdescribebyzip.head()
# Out:
#          price                                                              \
#          count          mean            std       min       25%        50%
# zipcode
# 98001    361.0  2.811949e+05   98837.430520  100000.0  215000.0   260000.0
# 98002    199.0  2.342840e+05   52041.448659   95000.0  199975.0   235000.0
# 98003    280.0  2.941113e+05  107597.662236  128000.0  229000.0   267475.0
# 98004    317.0  1.356524e+06  746094.067159  425000.0  845000.0  1150000.0
# 98005    168.0  8.102897e+05  268979.168276  400000.0  637775.0   765475.0
#
#                               bedrooms            ... sqft_living           \
#                75%        max    count      mean  ...         75%      max
# zipcode                                           ...
# 98001     320000.0   850000.0    361.0  3.393352  ...     2240.00   5440.0
# 98002     268500.0   389000.0    199.0  3.326633  ...     1984.00   3560.0
# 98003     330000.0   950000.0    280.0  3.357143  ...     2263.25   5774.0
# ...

# %%
data.
